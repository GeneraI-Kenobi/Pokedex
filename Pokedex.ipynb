# %%
import torch
import torch.nn as nn
from torchvision.transforms import transforms
import numpy as np
from torch.autograd import Variable
from torchvision.models import squeezenet1_1
import torch.functional as F
from io import open
import os
from PIL import Image
import pathlib
import glob
#import cv2

# %%
train_path = 'train'
pred_path = 'Check'

# %%
root=pathlib.Path(train_path)
classes=sorted([j.name.split('/')[-1] for j in root.iterdir()])

# %%
#CNN Network

class ConvNet(nn.Module):
    def __init__(self, num_pokemon = 151):
        super(ConvNet,self).__init__()
    
        #Input shape = (128, 3, 150, 150)
    
        #Output size after convolution = 150
    
        self.conv1 = nn.Conv2d(in_channels = 3, out_channels = 12, kernel_size = 3, stride = 1, padding = 1)
        #Shape = (128, 12, 150, 150)
        self.bn1 = nn.BatchNorm2d(num_features = 12)
        #Shape = (128,12,150,150)
        self.relu1 = nn.ReLU()
    
        self.pool = nn.MaxPool2d(kernel_size = 2)
        #Reduce the image size by factor of 2
        #Shape = (128, 12, 75,75)
    
        self.conv2 = nn.Conv2d(in_channels = 12, out_channels = 20, kernel_size = 3, stride = 1, padding = 1)
        #Shape = (128, 20, 75, 75)
        self.relu2 = nn.ReLU()
        #Shape = (128,20,75,75)
    
        self.conv3 = nn.Conv2d(in_channels = 20, out_channels = 32, kernel_size = 3, stride = 1, padding = 1)
        #Shape = (128, 32, 75, 75)
        self.bn3 = nn.BatchNorm2d(num_features = 32)
        #Shape = (128,32,75,75)
        self.relu3 = nn.ReLU()
        #Shape = (128, 32, 75, 75)
    
        self.fc = nn.Linear(in_features = 32*75*75, out_features = num_pokemon)
    
        #Feed forward function
    
    def forward(self, input):
        output = self.conv1(input)
        output = self.bn1(output)
        output = self.relu1(output)
        
        output = self.pool(output)
        
        output = self.conv2(output)
        output = self.relu2(output)
        
        output = self.conv3(output)
        output = self.bn3(output)
        output = self.relu3(output)
        
        #Above outpput will be in matrix form, with shape (128, 32, 75, 75)
        
        output = output.view(-1, 32*75*75)
        
        output = self.fc(output)
        
        return output

# %%
checkpoint = torch.load('best_checkpoint.model')
model = ConvNet(num_pokemon = 151)
model.load_state_dict(checkpoint)
model.eval()
# Out:
# ConvNet(
#   (conv1): Conv2d(3, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn1): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu1): ReLU()
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(12, 20, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (relu2): ReLU()
#   (conv3): Conv2d(20, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu3): ReLU()
#   (fc): Linear(in_features=180000, out_features=151, bias=True)
# )

# %%
transformer = transforms.Compose([
    transforms.Resize((150,150)),
    transforms.ToTensor(),
    transforms.Normalize([0.5, 0.5, 0.5], 
                         [0.5, 0.5, 0.5])
])

# %%
#prediction function

def prediction(img_path, transformer):
    
    image = Image.open(img_path)
    
    image_tensor = transformer(image).float()
    
    image_tensor = image_tensor.unsqueeze_(0)
    
    if torch.cuda.is_available():
        image_tensor.cuda()
    
    input = Variable(image_tensor)
    
    output = model(input)
    
    index = output.data.numpy().argmax()
    
    pred = classes[index]
    
    return pred

# %%
images_path = glob.glob(pred_path + '/*.jpg')

# %%
pred_dict = {}

for i in images_path:
    pred_dict[i[i.rfind('/') + 1:]] = prediction(i,transformer)

# %%
pred_dict
# Out:
# {'Check\\1.jpg': 'Bulbasaur',
#  'Check\\10.jpg': 'Caterpie',
#  'Check\\100.jpg': 'Voltorb',
#  'Check\\101.jpg': 'Electrode',
#  'Check\\102.jpg': 'Exeggcute',
#  'Check\\103.jpg': 'Exeggutor',
#  'Check\\104.jpg': 'Cubone',
#  'Check\\105.jpg': 'Marowak',
#  'Check\\106.jpg': 'Hitmonlee',
#  'Check\\107.jpg': 'Hitmonchan',
#  'Check\\108.jpg': 'Lickitung',
#  'Check\\109.jpg': 'Koffing',
#  'Check\\11.jpg': 'Metapod',
#  'Check\\110.jpg': 'Weezing',
#  'Check\\111.jpg': 'Rhyhorn',
#  'Check\\112.jpg': 'Rhydon',
#  'Check\\113.jpg': 'Chansey',
#  'Check\\114.jpg': 'Tangela',
#  'Check\\115.jpg': 'Kangaskhan',
#  'Check\\116.jpg': 'Horsea',
#  'Check\\117.jpg': 'Seadra',
#  'Check\\118.jpg': 'Goldeen',
#  'Check\\119.jpg': 'Seaking',
#  'Check\\12.jpg': 'Butterfree',
#  'Check\\120.jpg': 'Staryu',
#  'Check\\121.jpg': 'Starmie',
#  'Check\\122.jpg': 'MrMime',
#  'Check\\123.jpg': 'Scyther',
#  'Check\\124.jpg': 'Jynx',
#  'Check\\125.jpg': 'Mankey',
#  'Check\\126.jpg': 'Magmar',
#  'Check\\127.jpg': 'Pinsir',
#  'Check\\128.jpg': 'Tauros',
#  'Check\\129.jpg': 'Magikarp',
#  'Check\\13.jpg': 'Weedle',
#  'Check\\130.jpg': 'Gyarados',
#  'Check\\131.jpg': 'Lapras',
#  'Check\\132.jpg': 'Ditto',
#  'Check\\133.jpg': 'Eevee',
#  'Check\\134.jpg': 'Vaporeon',
#  'Check\\135.jpg': 'Ponyta',
#  'Check\\136.jpg': 'Fearow',
#  'Check\\137.jpg': 'Porygon',
#  'Check\\138.jpg': 'Omanyte',
#  'Check\\139.jpg': 'Omastar',
#  'Check\\14.jpg': 'Kakuna',
#  'Check\\140.jpg': 'Kabuto',
#  'Check\\141.jpg': 'Kabutops',
#  'Check\\142.jpg': 'Mankey',
#  'Check\\143.jpg': 'Snorlax',
#  'Check\\144.jpg': 'Articuno',
#  'Check\\145.jpg': 'Zapdos',
#  'Check\\146.jpg': 'Moltres',
#  'Check\\147.jpg': 'Dratini',
#  'Check\\148.jpg': 'Dragonair',
#  'Check\\149.jpg': 'Dragonite',
#  'Check\\15.jpg': 'Beedrill',
#  'Check\\150.jpg': 'Mewtwo',
#  'Check\\151.jpg': 'Mew',
#  'Check\\16.jpg': 'Pidgey',
#  'Check\\17.jpg': 'Pidgeotto',
#  'Check\\18.jpg': 'Pidgeot',
#  'Check\\19.jpg': 'Rattata',
#  'Check\\2.jpg': 'Ivysaur',
#  'Check\\20.jpg': 'Raticate',
#  'Check\\21.jpg': 'Spearow',
#  'Check\\22.jpg': 'Lapras',
#  'Check\\23.jpg': 'Ekans',
#  'Check\\24.jpg': 'Shellder',
#  'Check\\25.jpg': 'Pikachu',
#  'Check\\26.jpg': 'Raichu',
#  'Check\\27.jpg': 'Sandshrew',
#  'Check\\28.jpg': 'Sandslash',
#  'Check\\29.jpg': 'Nidorina',
#  'Check\\3.jpg': 'Venusaur',
#  'Check\\30.jpg': 'Nidorina',
#  'Check\\31.jpg': 'Nidoqueen',
#  'Check\\32.jpg': 'Nidorino',
#  'Check\\33.jpg': 'Nidorino',
#  'Check\\34.jpg': 'Nidoking',
#  'Check\\35.jpg': 'Clefairy',
#  'Check\\36.jpg': 'Clefable',
#  'Check\\37.jpg': 'Vulpix',
#  'Check\\38.jpg': 'Ninetales',
#  'Check\\39.jpg': 'Jigglypuff',
#  'Check\\4.jpg': 'Charmander',
#  'Check\\40.jpg': 'Wigglytuff',
#  'Check\\41.jpg': 'Zubat',
#  'Check\\42.jpg': 'Golbat',
#  'Check\\43.jpg': 'Oddish',
#  'Check\\44.jpg': 'Gloom',
#  'Check\\45.jpg': 'Vileplume',
#  'Check\\46.jpg': 'Paras',
#  'Check\\47.jpg': 'Parasect',
#  'Check\\48.jpg': 'Venonat',
#  'Check\\49.jpg': 'Venomoth',
#  'Check\\5.jpg': 'Charmeleon',
#  'Check\\50.jpg': 'Diglett',
#  'Check\\51.jpg': 'Dugtrio',
#  'Check\\52.jpg': 'Meowth',
#  'Check\\53.jpg': 'Persian',
#  'Check\\54.jpg': 'Psyduck',
#  'Check\\55.jpg': 'Golduck',
#  'Check\\56.jpg': 'Mankey',
#  'Check\\57.jpg': 'Primeape',
#  'Check\\58.jpg': 'Growlithe',
#  'Check\\59.jpg': 'Arcanine',
#  'Check\\6.jpg': 'Charizard',
#  'Check\\60.jpg': 'Poliwag',
#  'Check\\61.jpg': 'Poliwhirl',
#  'Check\\62.jpg': 'Poliwrath',
#  'Check\\63.jpg': 'Abra',
#  'Check\\64.jpg': 'Kadabra',
#  'Check\\65.jpg': 'Alakazam',
#  'Check\\66.jpg': 'Machop',
#  'Check\\67.jpg': 'Machoke',
#  'Check\\68.jpg': 'Machamp',
#  'Check\\69.jpg': 'Bellsprout',
#  'Check\\7.jpg': 'Squirtle',
#  'Check\\70.jpg': 'Weepinbell',
#  'Check\\71.jpg': 'Victreebel',
#  'Check\\72.jpg': 'Tentacool',
#  'Check\\73.jpg': 'Tentacruel',
#  'Check\\74.jpg': 'Geodude',
#  'Check\\75.jpg': 'Graveler',
#  'Check\\76.jpg': 'Golem',
#  'Check\\77.jpg': 'Ponyta',
#  'Check\\78.jpg': 'Rapidash',
#  'Check\\79.jpg': 'Slowpoke',
#  'Check\\8.jpg': 'Wartortle',
#  'Check\\80.jpg': 'Slowbro',
#  'Check\\81.jpg': 'Magnemite',
#  'Check\\82.jpg': 'Magneton',
#  'Check\\83.jpg': 'Farfetchd',
#  'Check\\84.jpg': 'Doduo',
#  'Check\\85.jpg': 'Dodrio',
#  'Check\\86.jpg': 'Seel',
#  'Check\\87.jpg': 'Dewgong',
#  'Check\\88.jpg': 'Grimer',
#  'Check\\89.jpg': 'Grimer',
#  'Check\\9.jpg': 'Blastoise',
#  'Check\\90.jpg': 'Shellder',
#  'Check\\91.jpg': 'Cloyster',
#  'Check\\92.jpg': 'Gastly',
#  'Check\\93.jpg': 'Haunter',
#  'Check\\94.jpg': 'Gengar',
#  'Check\\95.jpg': 'Onix',
#  'Check\\96.jpg': 'Drowzee',
#  'Check\\97.jpg': 'Hypno',
#  'Check\\98.jpg': 'Krabby',
#  'Check\\99.jpg': 'Krabby'}
